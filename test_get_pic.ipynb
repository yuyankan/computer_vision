# %%
import cv2

# --- 配置NVR信息 ---
nvr_ip_address = "147.121.119.88"  # 替换为您的NVR的IP地址
rtsp_port = "554"                 # RTSP端口，通常是554
username = "lgmpublic"                # 替换为您的NVR用户名
password = "Avery@1234"    # !!! 替换为您的NVR密码 !!!

# 您想访问的摄像机在NVR上的通道号 (例如，NVR上的D1通道通常是1)
# 假设您想访问的sensor (摄像机) 在NVR上被配置为通道1
channel_id = 12

# 选择码流类型: 1为主码流, 2为子码流
# 例如，通道1的主码流用 101, 子码流用 102
# 通道2的主码流用 201, 子码流用 202, 以此类推
stream_type_id_main = "01" # 主码流
stream_type_id_sub = "02"  # 子码流

# 构建RTSP URL (此处以主码流为例)
# rtsp_url = f"rtsp://{username}:{password}@{nvr_ip_address}:{rtsp_port}/Streaming/Channels/{channel_id}{stream_type_id_main}"
# 或者更常见的拼接方式 (对于海康设备，如通道1主码流为101，通道13主码流为1301):
rtsp_channel_identifier = str(channel_id) + stream_type_id_main
rtsp_url = f"rtsp://{username}:{password}@{nvr_ip_address}:{rtsp_port}/Streaming/Channels/{rtsp_channel_identifier}"

print(f"尝试连接到RTSP流: {rtsp_url.replace(password, '********')}") # 打印URL，隐藏密码

# 创建VideoCapture对象
cap = cv2.VideoCapture(rtsp_url)

# 检查连接是否成功
if not cap.isOpened():
    print("错误：无法打开视频流。请检查：")
    print(f"1. NVR IP地址 ({nvr_ip_address}) 和端口 ({rtsp_port}) 是否正确且可达。")
    print(f"2. NVR用户名 ({username}) 和密码是否正确。")
    print(f"3. 通道号 ({channel_id}) 和码流类型 ({stream_type_id_main}) 是否正确配置并可用。")
    print("4. RTSP服务是否在NVR上启用，并且网络防火墙没有阻止连接。")
    print("5. OpenCV是否正确安装并能处理RTSP流 (可能需要FFmpeg支持)。")
    exit()

print("视频流连接成功！按 'q' 键退出。")

while True:
    # 逐帧读取视频
    ret, frame = cap.read()

    # 如果成功读取帧
    if ret:
        # 在此处可以加入您的识别模型代码对 'frame' 进行处理
        # 例如: processed_frame = your_recognition_model(frame)
        
        # 显示原始帧 (或处理后的帧)
        cv2.imshow(f'NVR Channel {channel_id} - {nvr_ip_address}', frame)

        # 检测按键，如果按下 'q' 则退出循环
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        print("错误：无法读取视频帧，可能码流已结束或连接中断。")
        break

# 释放VideoCapture对象并关闭所有OpenCV窗口
cap.release()
cv2.destroyAllWindows()
# Out:
# 尝试连接到RTSP流: rtsp://lgmpublic:********@147.121.119.88:554/Streaming/Channels/101
# 视频流连接成功！按 'q' 键退出。

# %% [markdown]
# # get vedeo and run model and alert

# %%
import cv2
import datetime
import time
import os

# --- 配置NVR信息 ---
# --- 配置NVR信息 ---
nvr_ip_address = "147.121.119.88"  # 替换为您的NVR的IP地址
rtsp_port = "554"                 # RTSP端口，通常是554
username = "lgmpublic"                # 替换为您的NVR用户名
password = "Avery@1234"    # !!! 替换为您的NVR密码 !!!

channel_id = 12                    # 您想访问的摄像机在NVR上的通道号
stream_type_id = "01"             # 01为主码流, 02为子码流 (例如通道1主码流为101)

rtsp_channel_identifier = str(channel_id) + stream_type_id
rtsp_url = f"rtsp://{username}:{password}@{nvr_ip_address}:{rtsp_port}/Streaming/Channels/{rtsp_channel_identifier}"

# --- 配置截图和日志 ---
SCREENSHOT_DIR = "screenshots"
LOG_FILE = "alarm_log.txt"

if not os.path.exists(SCREENSHOT_DIR):
    os.makedirs(SCREENSHOT_DIR)

def log_alarm(message):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_entry = f"[{timestamp}] {message}\n"
    print(log_entry.strip()) # 打印到控制台
    with open(LOG_FILE, "a") as f:
        f.write(log_entry)

# --- 模型集成占位符 ---
# 假设您有一个函数可以加载您的模型 (在程序开始时加载一次)
# my_helmet_model = load_my_custom_model("path/to/your/model_weights")

def your_custom_model_inference(frame):
    """
    这是一个占位符函数。您需要用您自己的模型推理代码替换它。
    输入: frame (OpenCV格式的图像帧 BGR)
    输出: 一个检测结果列表。每个结果可以是一个字典或对象，包含：
           'class_name': 'person', 'no_helmet_person', 'helmet' 等
           'bbox': [x, y, width, height] 边界框
           'confidence': 置信度 (0到1)
    
    示例模拟输出:
    detections = [
        {'class_name': 'person', 'bbox': [100, 100, 50, 150], 'confidence': 0.9},
        {'class_name': 'person_no_helmet', 'bbox': [200, 150, 60, 160], 'confidence': 0.85}, # 假设模型能直接输出这个类别
    ]
    return detections
    """
    # 为了演示，这里模拟一些检测结果 (每隔几秒随机触发一次)
    # 在实际应用中，删除这部分模拟代码，并集成您的真实模型
    detections = []
    if int(time.time()) % 10 < 2: # 每10秒中的2秒模拟检测到未戴安全帽人员
        detections.append({
            'class_name': 'person_no_helmet', # 或者您的模型输出 'person' 和 'no_helmet' 分开，需要额外逻辑判断
            'bbox': [50, 50, 100, 200], # 示例边界框
            'confidence': 0.9
        })
        detections.append({
             'class_name': 'person',
             'bbox': [200, 60, 80, 180],
             'confidence': 0.8
        })

    return detections

# --- 主程序 ---
def main():
    print(f"尝试连接到RTSP流: {rtsp_url.replace(password, '********')}")
    cap = cv2.VideoCapture(rtsp_url)

    if not cap.isOpened():
        log_alarm(f"错误：无法打开视频流 {rtsp_url.replace(password, '********')}")
        print("请检查NVR IP、端口、用户名、密码、通道号及网络连接。")
        return

    print("视频流连接成功！按 'q' 键退出。")
    
    last_alarm_time = 0
    alarm_cooldown = 5 # 秒，同一目标的报警冷却时间，避免过于频繁

    while True:
        ret, frame = cap.read()
        if not ret:
            log_alarm("错误：无法读取视频帧，码流可能已结束或连接中断。")
            break

        # 1. 模型推理
        # 注意：根据您的模型，可能需要对frame进行预处理 (如缩放、归一化等)
        # preprocessed_frame = preprocess_frame_for_your_model(frame)
        # detections = my_helmet_model.predict(preprocessed_frame) # 调用您实际模型的推理
        
        detections = your_custom_model_inference(frame.copy()) # 使用占位符，传入副本以防模型修改原帧

        # 2. 处理检测结果并触发报警
        person_detected_no_helmet_this_frame = False
        for detection in detections:
            class_name = detection.get('class_name')
            bbox = detection.get('bbox')
            confidence = detection.get('confidence', 0)

            # 核心逻辑：检测到 "person_no_helmet" 或通过组合逻辑判断 "person" 且 "no_helmet"
            # 以下示例假设模型可以直接输出 'person_no_helmet' 类别
            # 或者，如果模型输出 'person' 和 'no_helmet' 分开，您需要实现逻辑来关联它们
            if class_name == 'person_no_helmet' and confidence > 0.7: # 设置一个置信度阈值
                person_detected_no_helmet_this_frame = True
                
                # 绘制边界框 (可选)
                if bbox:
                    x, y, w, h = bbox
                    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
                    cv2.putText(frame, f"{class_name} ({confidence:.2f})", (x, y - 10), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
                
                # 触发报警 (带冷却时间)
                current_time = time.time()
                if current_time - last_alarm_time > alarm_cooldown:
                    timestamp_file = datetime.datetime.now().strftime("%Y%m%d_%H%M%S_%f")
                    screenshot_filename = os.path.join(SCREENSHOT_DIR, f"no_helmet_alarm_{timestamp_file}.jpg")
                    cv2.imwrite(screenshot_filename, frame)
                    
                    alarm_message = f"报警：检测到未佩戴安全帽人员！截图已保存至 {screenshot_filename}"
                    if bbox:
                        alarm_message += f" 位置大致在: x={bbox[0]}, y={bbox[1]}"
                    log_alarm(alarm_message)
                    
                    last_alarm_time = current_time
                    # 在此可以添加其他报警方式，如发送网络请求、播放声音等
                    # e.g., send_network_alert(), play_alarm_sound()

            elif class_name == 'person' and bbox: # 如果只是普通人员，也画个框 (可选)
                 x, y, w, h = bbox
                 cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 1)
                 cv2.putText(frame, f"{class_name} ({confidence:.2f})", (x, y - 10), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)


        # 3. 显示结果帧
        cv2.imshow(f'Safety Helmet Detection - NVR Channel {channel_id}', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    log_alarm("程序已停止。")

if __name__ == '__main__':
    main()
# Out:
# 尝试连接到RTSP流: rtsp://lgmpublic:********@147.121.119.88:554/Streaming/Channels/1201
# 视频流连接成功！按 'q' 键退出。
# [2025-05-29 15:27:20] 报警：检测到未佩戴安全帽人员！截图已保存至 screenshots\no_helmet_alarm_20250529_152720_030040.jpg 位置大致在: x=50, y=50
# [2025-05-29 15:27:30] 报警：检测到未佩戴安全帽人员！截图已保存至 screenshots\no_helmet_alarm_20250529_152730_031627.jpg 位置大致在: x=50, y=50
# [2025-05-29 15:27:40] 报警：检测到未佩戴安全帽人员！截图已保存至 screenshots\no_helmet_alarm_20250529_152740_033029.jpg 位置大致在: x=50, y=50
# [2025-05-29 15:27:50] 报警：检测到未佩戴安全帽人员！截图已保存至 screenshots\no_helmet_alarm_20250529_152750_062430.jpg 位置大致在: x=50, y=50

# %%
class CFG:
    ### inference: use any pretrained or custom model
    # WEIGHTS = 'yolov8x.pt' # yolov8n.pt, yolov8s.pt, yolov8m.pt, yolov8l.pt, yolov8x.pt
    WEIGHTS = '/kaggle/input/yolov8-finetuning-for-ppe-detection/runs/detect/yolov8s_ppe_css_50_epochs/weights/best.pt'
    
    CONFIDENCE = 0.60
    CONFIDENCE_INT = int( round(CONFIDENCE * 100, 0) )
    
    CLASSES_TO_DETECT = [0, 2, 4, 5, 7] # Hardhat, NO-Hardhat, NO-Safety Vest, Person, Safety Vest
    
    VERTICES_POLYGON = np.array([[200,720], [0,700], [500,620], [990,690], [820,720]])

    EXP_NAME = 'ppe'

    ### just some video examples
    VID_001 = '/kaggle/input/video-example-for-ppe-red-zone/example_video.mp4'

    ### choose filepath to make inference on (image or video)
    PATH_TO_INFER_ON = VID_001
    EXT = PATH_TO_INFER_ON.split('.')[-1] # get file extension
    FILENAME_TO_INFER_ON = PATH_TO_INFER_ON.split('/')[-1].split('.')[0] # get filename

    ### paths
    ROOT_DIR = '/kaggle/input/video-example-for-ppe-red-zone/'
    OUTPUT_DIR = './'

# %%
# v2

# %%
import cv2
import datetime
import time
import os
from ultralytics import YOLO # 导入YOLO

# %% [markdown]
# CSS (Construction Site Safety) Dataset:
#
# Labels in this dataset:
# 0: Hardhat
# 1: Mask
# 2: NO-Hardhat
# 3: NO-Mask
# 4: NO-Safety Vest
# 5: Person
# 6: Safety Cone
# 7: Safety Vest
# 8: Machinery
# 9: Vehicle
# More info:
# Number of classes: 10
# Label Annotation: YOLO format (.txt)
# [class_id, center_x, center_y, width, height]

# %%
def get_nvr():

    # --- 配置NVR信息 ---
    nvr_ip_address = "147.121.119.88"  # 替换为您的NVR的IP地址
    rtsp_port = "554"                 # RTSP端口，通常是554
    username = "lgmpublic"                # 替换为您的NVR用户名
    password = "Avery@1234"    # !!! 替换为您的NVR密码 !!!

    channel_id = 12                   # 您想访问的摄像机在NVR上的通道号
    stream_type_id = "01"             # 01为主码流, 02为子码流 (例如通道1主码流为101)

    rtsp_channel_identifier = str(channel_id) + stream_type_id
    rtsp_url = f"rtsp://{username}:{password}@{nvr_ip_address}:{rtsp_port}/Streaming/Channels/{rtsp_channel_identifier}"
    print(f"尝试连接到RTSP流: {rtsp_url.replace(password, '********')}")

  
    cap = cv2.VideoCapture(rtsp_url)

    if not cap.isOpened():
        log_alarm(f"错误：无法打开视频流 {rtsp_url.replace(password, '********')}")
        return

    print("视频流连接成功！按 'q' 键退出。")
    return cap

# --- 配置截图和日志 ---
SCREENSHOT_DIR = "screenshots_yolo"
LOG_FILE = "alarm_log_yolo.txt"


class CFG:
    ### inference: use any pretrained or custom model
    # WEIGHTS = 'yolov8x.pt' # yolov8n.pt, yolov8s.pt, yolov8m.pt, yolov8l.pt, yolov8x.pt
    WEIGHTS = 'yolov8n.pt'
    
    CONFIDENCE = 0.60
    CONFIDENCE_INT = int( round(CONFIDENCE * 100, 0) )
    
    CLASSES_TO_DETECT = [2, 3, 4, 5] 

def model_set():

    #address to save screenshot
    if not os.path.exists(SCREENSHOT_DIR):
        os.makedirs(SCREENSHOT_DIR)
    
    # --- 加载YOLOv8模型 ---
    # !!! 重要: 请确保 'yolov8n.pt' 是您自定义训练过的模型，
    # 包含 'person' 和 'helmet' (或类似) 类别 !!!
    try:
        model = YOLO(CFG.WEIGHTS) # 替换为您的模型文件路径
        if torch.cuda.is_available():
            model.to('cuda:0')
        else:
            print("CUDA device is not available. Running on CPU.")
    
        # 打印模型识别的类别，以便您核对 (可选)
        # print(f"模型加载成功。识别类别: {model.names}")
        # 假设您的模型类别: 0: 'person', 1: 'helmet' (这需要根据您的模型调整)
        # 您可以通过 model.names 来获取真实的类别映射
        # 例如: class_names = model.names
        # person_class_id = [k for k, v in class_names.items() if v == 'person'][0]
        # helmet_class_id = [k for k, v in class_names.items() if v == 'helmet'][0]
        # 为简化，我们直接使用假定的类别名称，实际应从model.names获取或硬编码正确的ID
        return model
    except Exception as e:
        log_alarm(f"错误：无法加载YOLOv8模型 '{model_path}'. 错误信息: {e}")
        print("请确保模型文件路径正确，且Ultralytics已正确安装。")
        exit()


def log_alarm(message):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_entry = f"[{timestamp}] {message}\n"
    print(log_entry.strip()) # 打印到控制台
    with open(LOG_FILE, "a", encoding='utf-8') as f: # 指定UTF-8编码
        f.write(log_entry)


# --- 辅助函数：判断头盔是否在人头上 (简易版) ---
def is_helmet_on_person(person_bbox, helmet_bbox, frame_height):
    """
    简易逻辑判断头盔是否在人头上。
    person_bbox: [x1, y1, x2, y2]
    helmet_bbox: [x1, y1, x2, y2]
    """
    px1, py1, px2, py2 = person_bbox
    hx1, hy1, hx2, hy2 = helmet_bbox

    person_width = px2 - px1
    person_head_y_upper_limit = py1 + (py2 - py1) * 0.3 # 假设头部在人体上半部分30%区域
    
    # 头盔中心点
    helmet_center_x = (hx1 + hx2) / 2
    helmet_center_y = (hy1 + hy2) / 2

    # 1. 头盔是否在人的垂直上方区域
    is_above = hy2 < person_head_y_upper_limit # 头盔的底部应该在人头区域的上限之上或之内
    is_vertically_close = hy1 < py2 # 头盔顶部应该在人的底部之上

    # 2. 头盔是否在人的水平中心区域附近
    is_horizontally_aligned = (px1 - person_width*0.3) < helmet_center_x < (px2 + person_width*0.3)

    # 3. 头盔不能太低 (例如，不能低于人的中点)
    is_not_too_low = helmet_center_y < (py1 + (py2 - py1) * 0.5)
    
    # 4. 可以增加面积重叠或比例判断
    # 简单的判断：头盔在人头大致区域内
    if is_horizontally_aligned and hy1 < person_head_y_upper_limit and hy2 > py1 * 0.8 and hy1 < py1 + (py2-py1)*0.4 : # 头盔的Y轴与人的头部区域有重叠
         # 进一步检查X轴重叠
        overlap_x = max(0, min(px2, hx2) - max(px1, hx1))
        if overlap_x / min(px2-px1, hx2-hx1) > 0.3: # X轴重叠超过30%
            return True
            
    return False


# --- 主程序 ---
def main():

    cap = get_nvr()
    
    last_alarm_times = {} # 用于跟踪每个检测到的人的报警冷却时间
    alarm_cooldown = 15 # 秒，同一目标的报警冷却时间

    frame_count = 0
    process_every_n_frames = 15 # 每隔几帧处理一次，降低负载，可调整

    model = model_set()
    if not model:
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            log_alarm("错误：无法读取视频帧，码流可能已结束或连接中断。")
            break
        
        frame_count += 1
        
        if frame_count % process_every_n_frames != 0:
            # 显示未处理的帧 (可选，可提高显示帧率)
            #cv2.imshow(f'Safety Helmet Detection - NVR Channel {channel_id}', frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
            continue
            


        # 1. YOLOv8 模型推理
        # verbose=False 关闭冗余输出
        results = model.predict(
                        source = frame,
                        save = True,
                        classes = CFG.CLASSES_TO_DETECT,
                        conf = CFG.CONFIDENCE,
                        save_txt = True,
                        save_conf = True,
                        show = True,
                        device = [0,1],
                    #     stream = True,
                    ) # conf是置信度阈值

        
        # 3. 显示结果帧
        cv2.imshow(f'Safety Helmet Detection - NVR Channel {channel_id}', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    log_alarm("程序已停止。")

# %%
main()
# Out:
# 尝试连接到RTSP流: rtsp://lgmpublic:********@147.121.119.88:554/Streaming/Channels/1201
# 视频流连接成功！按 'q' 键退出。
# [2025-05-27 13:11:48] 报警：检测到未佩戴安全帽人员 (人员 1)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131148_854661_person0.jpg
# [2025-05-27 13:11:48] 报警：检测到未佩戴安全帽人员 (人员 2)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131148_862933_person1.jpg
# [2025-05-27 13:11:49] 报警：检测到未佩戴安全帽人员 (人员 1)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131149_321121_person0.jpg
# [2025-05-27 13:11:49] 报警：检测到未佩戴安全帽人员 (人员 1)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131149_825730_person0.jpg
# [2025-05-27 13:11:49] 报警：检测到未佩戴安全帽人员 (人员 2)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131149_834491_person1.jpg
# [2025-05-27 13:11:50] 报警：检测到未佩戴安全帽人员 (人员 1)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131150_561115_person0.jpg
# [2025-05-27 13:11:51] 报警：检测到未佩戴安全帽人员 (人员 1)！截图已保存至 screenshots_yolo\no_helmet_alarm_20250527_131151_098912_person0.jpg
# ...
